# %% [markdown]
# ### Imports ###

# %%
# %matplotlib widget
import numpy as np
from ksp_interface import GuidanceHelperFunctions as ghf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import krpc
import json
import time
import random
from scipy.spatial import Delaunay
from numpy.polynomial.legendre import legvander2d
from scipy.interpolate import Rbf
from sklearn.metrics import r2_score
import scipy.linalg as la
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ### Connect to KRPc Server ###

# %%
conn = krpc.connect(name='KRPC Test')
print(conn.krpc.get_status().version)
vessel = conn.space_center.active_vessel
kerbin = conn.space_center.bodies['Kerbin']
celest_refframe = kerbin.non_rotating_reference_frame # This doesn't seem to work any better really
vessel_refframe = vessel.reference_frame
session = (conn, vessel, celest_refframe)
# Out:
# 0.5.4

# %% [markdown]
# ### KSP Indirect Frame to PyOptFlight Direct Frame Function ###

# %%
def ksp2pyoptflight(coords: np.ndarray):
    coords = np.atleast_2d(coords)
    x = coords[:, 0]
    y = coords[:, 2]
    z = coords[:, 1]
    return np.column_stack((x, y, z))

# %% [markdown]
# ### Collect Aerodynamic Data Randomly ###

# %%
nsamples = 10000
M_max = 25
A_ref = (1.25/2)**2*np.pi

# All in KSP coordinate system!
start_time = time.time()
a = vessel.flight().speed_of_sound
rho = vessel.flight().atmosphere_density
pos = np.array(vessel.position(celest_refframe))
wind = np.cross(np.array(kerbin.angular_velocity(celest_refframe)), pos)

ebx = np.array(conn.space_center.transform_direction([1, 0, 0], vessel_refframe, celest_refframe))
eby = np.array(conn.space_center.transform_direction([0, 1, 0], vessel_refframe, celest_refframe))
ebz = np.array(conn.space_center.transform_direction([0, 0, 1], vessel_refframe, celest_refframe))

vel_dir_samples = np.empty((nsamples, 3))
mach_samples = np.empty((nsamples))
force_samples = np.empty((nsamples, 3))

for i in range(nsamples):
    # M = random.uniform(0, M_max)
    M = M_max*(np.random.rand()**2)
    phi = random.uniform(0, np.pi/2)
    theta = random.uniform(-np.pi, np.pi)

    vel_dir = ebx*np.cos(theta)*np.sin(phi) + eby*np.cos(phi) + ebz*np.sin(theta)*np.sin(phi)
    vel_rel = vel_dir*M*a
    # aero_force = vessel.flight(celest_refframe).simulate_aerodynamic_force_at(kerbin, pos, vel_rel+wind)
    initialize = True if i == 0 else False
    aero_force = np.array(conn.simulate_aerodynamic_forces.calculate_vessel_aero_force(
        pos, 
        vel_rel, 
        celest_refframe, 
        use_mls=True, 
        use_mcs=True, 
        initialize=initialize, 
        mls_mult=1000,
        pitch=0,
        yaw=0,
        roll=0,
        verbose=False
    ))

    mach_samples[i] = M
    vel_dir_samples[i] = vel_dir
    force_samples[i] = np.array(aero_force)

    if i%10 == 0:
        print(f'{100*(i+1)/nsamples:.1f} %, {time.time()-start_time:.2f} sec')

# %% [markdown]
# ### Collect Aerodynamic Data In Grids ###

# %%
nmach = 100
nphi = 10
ntheta = 10
nsamples = nmach*nphi*ntheta
print(f'Total samples: {nsamples}')
time.sleep(5)
M_max = 3
A_ref = (1.25/2)**2*np.pi

# All in KSP coordinate system!
start_time = time.time()
a = vessel.flight().speed_of_sound
rho = vessel.flight().atmosphere_density
pos = np.array(vessel.position(celest_refframe))
wind = np.cross(np.array(kerbin.angular_velocity(celest_refframe)), pos)

ebx = np.array(conn.space_center.transform_direction([1, 0, 0], vessel_refframe, celest_refframe))
eby = np.array(conn.space_center.transform_direction([0, 1, 0], vessel_refframe, celest_refframe))
ebz = np.array(conn.space_center.transform_direction([0, 0, 1], vessel_refframe, celest_refframe))

vel_dir_samples = np.empty((nsamples, 3))
mach_samples = np.empty((nsamples))
force_samples = np.empty((nsamples, 3))

M = np.linspace(1e-6, M_max, nmach)
phi = np.linspace(0, np.pi/2, nphi)
theta = np.linspace(-np.pi, np.pi, ntheta)

ncurrent = 0
for i in range(nmach):
    for j in range(nphi):
        for k in range(ntheta):

            vel_dir = ebx*np.cos(theta[k])*np.sin(phi[j]) + eby*np.cos(phi[j]) + ebz*np.sin(theta[k])*np.sin(phi[j])
            vel_rel = vel_dir*M[i]*a
            # aero_force = vessel.flight(celest_refframe).simulate_aerodynamic_force_at(kerbin, pos, vel_rel+wind)
            initialize = True if ncurrent == 0 else False
            aero_force = np.array(conn.simulate_aerodynamic_forces.calculate_vessel_aero_force(
                pos, 
                vel_rel, 
                celest_refframe, 
                use_mls=True, 
                use_mcs=True, 
                initialize=initialize, 
                mls_mult=1000,
                pitch=0,
                yaw=0,
                roll=0,
                verbose=False
            ))

            mach_samples[ncurrent] = M[i]
            vel_dir_samples[ncurrent] = vel_dir
            force_samples[ncurrent] = np.array(aero_force)

            if ncurrent%10 == 0:
                print(f'{100*(ncurrent+1)/nsamples:.1f} %, {time.time()-start_time:.2f} sec')

            ncurrent += 1

# %% [markdown]
# ### Collect Aerodynamic Data Averages For Each Axis Seperately

# %%
class TimeRemaining():
    def __init__(self, total_iters, avg_iter_time = None, alpha = 0.1):
        self.prev_time = time.time()
        self.alpha = alpha # weight on recent measurments
        self.avg_iter_time = avg_iter_time
        self.total_iters = total_iters
    def add_data(self):
        curr_time = time.time()
        iter_time = curr_time - self.prev_time
        if self.avg_iter_time == None:
            self.avg_iter_time = iter_time
        else:
            self.avg_iter_time = self.alpha * iter_time + (1 - self.alpha) * self.avg_iter_time
        self.prev_time = curr_time
    def get_time_remaining(self, iter):
        return self.avg_iter_time*(self.total_iters - iter)

A_ref = (1.25/2)**2*np.pi
a = vessel.flight().speed_of_sound
rho = vessel.flight().atmosphere_density
pos = np.array(vessel.position(celest_refframe))
wind = np.cross(np.array(kerbin.angular_velocity(celest_refframe)), pos)
conn.simulate_aerodynamic_forces.ensure_reflection_initialized() # Intialize reflection here for simulation, do this once

ebx = np.array(conn.space_center.transform_direction([1, 0, 0], vessel_refframe, celest_refframe))
eby = np.array(conn.space_center.transform_direction([0, 1, 0], vessel_refframe, celest_refframe))
ebz = np.array(conn.space_center.transform_direction([0, 0, 1], vessel_refframe, celest_refframe))
eBx = ksp2pyoptflight(eby)[0]
eBy = np.cross([0, 0, 1], eBx)
eBz = np.cross(eBx, eBy)

min_M, max_M, num_M = 1e-6, 25, 50
max_phi_x, max_phi_y, max_phi_z, num_AoA = np.pi/2, np.pi, np.pi, 50
nsamples = 10 # Number of samples to take at each point to average
min_theta_x, max_theta_x = -np.pi, np.pi 
min_theta_y, max_theta_y = 0, np.pi
min_theta_z, max_theta_z = -np.pi/2, np.pi/2
theta_x = np.linspace(min_theta_x, max_theta_x, nsamples)
theta_y = np.linspace(min_theta_y, max_theta_y, nsamples)
theta_z = np.linspace(min_theta_z, max_theta_z, nsamples)
theta_zip = list(zip(theta_x, theta_y, theta_z))

M = np.linspace(min_M, max_M, num_M)
cos_x = np.linspace(np.cos(max_phi_x), np.cos(0), num_AoA)
cos_y = np.linspace(np.cos(max_phi_y), np.cos(0), num_AoA)
cos_z = np.linspace(np.cos(max_phi_z), np.cos(0), num_AoA)
cos_zip = list(zip(cos_x, cos_y, cos_z))

ntotal = num_M*num_AoA
# should all have length ntotal
mach_ret = np.repeat(M, num_AoA)
cos_x_ret = np.tile(cos_x, num_M)
cos_y_ret = np.tile(cos_y, num_M)
cos_z_ret = np.tile(cos_z, num_M)
CA_ret  = np.empty(ntotal)
CNy_ret = np.empty(ntotal)
CNz_ret = np.empty(ntotal)

count = 0
abs_start_time = time.time()
time_rem_obj = TimeRemaining(ntotal, avg_iter_time = 0.07, alpha=0.05)
for mach in M: # Loop through the Mach samples
    vmag = a*mach
    divisor = (0.5*rho*vmag**2*A_ref)
    for (cx, cy, cz) in cos_zip: # Loop through the cosine angles we want ranges for (hemispheres centered on eBx)
        ### Initialize force sums for averaging
        Fx_sum  = 0
        Fy_sum = 0
        Fz_sum = 0
        sx, sy, sz = np.sqrt(1-cx**2), np.sqrt(1-cy**2), np.sqrt(1-cz**2)
        for (tx, ty, tz) in theta_zip: # Loop through sample points at constant cosine angles but different azimuthal angles to average
            vel_dir_x = eBx*cx + eBy*sx*np.cos(tx) + eBz*sx*np.sin(tx)
            vel_dir_y = eBy*cy + eBz*sy*np.cos(ty) + eBx*sy*np.sin(ty)
            vel_dir_z = eBz*cz + eBx*sz*np.cos(tz) + eBy*sz*np.sin(tz)

            vel_x = ksp2pyoptflight(vmag*vel_dir_x)[0]
            vel_y = ksp2pyoptflight(vmag*vel_dir_y)[0]
            vel_z = ksp2pyoptflight(vmag*vel_dir_z)[0]

            Fx = ksp2pyoptflight(np.array(conn.simulate_aerodynamic_forces.calculate_vessel_aero_force(
                pos, 
                vel_x, 
                celest_refframe, 
                initialize=False, 
                mls_mult=1000,
                verbose=False
            )))[0]
            Fy = ksp2pyoptflight(np.array(conn.simulate_aerodynamic_forces.calculate_vessel_aero_force(
                pos, 
                vel_y, 
                celest_refframe, 
                initialize=False, 
                mls_mult=1000,
                verbose=False
            )))[0]
            Fz = ksp2pyoptflight(np.array(conn.simulate_aerodynamic_forces.calculate_vessel_aero_force(
                pos, 
                vel_z, 
                celest_refframe, 
                initialize=False, 
                mls_mult=1000,
                verbose=False
            )))[0]

            Fx_sum  += np.dot(Fx, eBx)
            Fy_sum += np.dot(Fy, eBy)
            Fz_sum += np.dot(Fz, eBz)

        CA_ret[count] = Fx_sum/(nsamples*divisor)
        CNy_ret[count] = Fy_sum/(nsamples*divisor)
        CNz_ret[count] = Fz_sum/(nsamples*divisor)

        count += 1
        time_rem_obj.add_data()
        if count % 10 == 0:
            elapsed_time = time.time() - abs_start_time # Total time elapsed so far
            time_remaining = time_rem_obj.get_time_remaining(count)
            print(f'Count: {count}/{ntotal}, '+
                  f'time remaining: {time_remaining:.1f} sec, '+
                  f'rate average: {1/time_rem_obj.avg_iter_time:.3f} iter/sec, '+
                  f'elapsed: {elapsed_time:.1f} sec')
# Out:
# Count: 10/2500, time remaining: 170.1 sec, rate average: 14.641 iter/sec, elapsed: 0.7 sec
# Count: 20/2500, time remaining: 165.6 sec, rate average: 14.976 iter/sec, elapsed: 1.3 sec
# Count: 30/2500, time remaining: 163.8 sec, rate average: 15.081 iter/sec, elapsed: 2.0 sec
# Count: 40/2500, time remaining: 159.7 sec, rate average: 15.399 iter/sec, elapsed: 2.6 sec
# Count: 50/2500, time remaining: 153.4 sec, rate average: 15.967 iter/sec, elapsed: 3.2 sec
# Count: 60/2500, time remaining: 153.1 sec, rate average: 15.935 iter/sec, elapsed: 3.8 sec
# Count: 70/2500, time remaining: 149.9 sec, rate average: 16.213 iter/sec, elapsed: 4.4 sec
# Count: 80/2500, time remaining: 150.8 sec, rate average: 16.052 iter/sec, elapsed: 5.0 sec
# Count: 90/2500, time remaining: 148.0 sec, rate average: 16.281 iter/sec, elapsed: 5.6 sec
# Count: 100/2500, time remaining: 144.4 sec, rate average: 16.617 iter/sec, elapsed: 6.2 sec
# Count: 110/2500, time remaining: 147.7 sec, rate average: 16.178 iter/sec, elapsed: 6.9 sec
# Count: 120/2500, time remaining: 147.6 sec, rate average: 16.122 iter/sec, elapsed: 7.5 sec
# Count: 130/2500, time remaining: 147.1 sec, rate average: 16.109 iter/sec, elapsed: 8.1 sec
# Count: 140/2500, time remaining: 146.4 sec, rate average: 16.124 iter/sec, elapsed: 8.8 sec
# Count: 150/2500, time remaining: 146.0 sec, rate average: 16.092 iter/sec, elapsed: 9.4 sec
# Count: 160/2500, time remaining: 141.6 sec, rate average: 16.522 iter/sec, elapsed: 10.0 sec
# Count: 170/2500, time remaining: 139.6 sec, rate average: 16.691 iter/sec, elapsed: 10.5 sec
# Count: 180/2500, time remaining: 140.1 sec, rate average: 16.556 iter/sec, elapsed: 11.2 sec
# Count: 190/2500, time remaining: 139.3 sec, rate average: 16.579 iter/sec, elapsed: 11.8 sec
# Count: 200/2500, time remaining: 139.2 sec, rate average: 16.529 iter/sec, elapsed: 12.4 sec
# Count: 210/2500, time remaining: 137.8 sec, rate average: 16.621 iter/sec, elapsed: 13.0 sec
# Count: 220/2500, time remaining: 139.9 sec, rate average: 16.301 iter/sec, elapsed: 13.6 sec
# Count: 230/2500, time remaining: 137.1 sec, rate average: 16.557 iter/sec, elapsed: 14.2 sec
# Count: 240/2500, time remaining: 139.3 sec, rate average: 16.220 iter/sec, elapsed: 14.8 sec
# Count: 250/2500, time remaining: 138.2 sec, rate average: 16.286 iter/sec, elapsed: 15.4 sec
# Count: 260/2500, time remaining: 151.0 sec, rate average: 14.835 iter/sec, elapsed: 16.2 sec
# Count: 270/2500, time remaining: 145.4 sec, rate average: 15.342 iter/sec, elapsed: 16.9 sec
# Count: 280/2500, time remaining: 139.4 sec, rate average: 15.922 iter/sec, elapsed: 17.4 sec
# Count: 290/2500, time remaining: 154.9 sec, rate average: 14.265 iter/sec, elapsed: 18.2 sec
# Count: 300/2500, time remaining: 158.5 sec, rate average: 13.880 iter/sec, elapsed: 19.0 sec
# Count: 310/2500, time remaining: 147.8 sec, rate average: 14.822 iter/sec, elapsed: 19.6 sec
# Count: 320/2500, time remaining: 143.5 sec, rate average: 15.191 iter/sec, elapsed: 20.2 sec
# Count: 330/2500, time remaining: 139.8 sec, rate average: 15.523 iter/sec, elapsed: 20.9 sec
# Count: 340/2500, time remaining: 141.2 sec, rate average: 15.300 iter/sec, elapsed: 21.5 sec
# Count: 350/2500, time remaining: 139.3 sec, rate average: 15.436 iter/sec, elapsed: 22.2 sec
# Count: 360/2500, time remaining: 141.5 sec, rate average: 15.128 iter/sec, elapsed: 22.9 sec
# Count: 370/2500, time remaining: 136.3 sec, rate average: 15.627 iter/sec, elapsed: 23.5 sec
# Count: 380/2500, time remaining: 133.5 sec, rate average: 15.877 iter/sec, elapsed: 24.1 sec
# Count: 390/2500, time remaining: 138.0 sec, rate average: 15.290 iter/sec, elapsed: 24.8 sec
# Count: 400/2500, time remaining: 129.7 sec, rate average: 16.194 iter/sec, elapsed: 25.3 sec
# Count: 410/2500, time remaining: 128.1 sec, rate average: 16.316 iter/sec, elapsed: 25.9 sec
# Count: 420/2500, time remaining: 123.2 sec, rate average: 16.881 iter/sec, elapsed: 26.5 sec
# Count: 430/2500, time remaining: 124.3 sec, rate average: 16.652 iter/sec, elapsed: 27.1 sec
# Count: 440/2500, time remaining: 123.7 sec, rate average: 16.647 iter/sec, elapsed: 27.7 sec
# Count: 450/2500, time remaining: 118.7 sec, rate average: 17.263 iter/sec, elapsed: 28.3 sec
# Count: 460/2500, time remaining: 118.2 sec, rate average: 17.259 iter/sec, elapsed: 28.8 sec
# Count: 470/2500, time remaining: 115.8 sec, rate average: 17.528 iter/sec, elapsed: 29.4 sec
# Count: 480/2500, time remaining: 116.7 sec, rate average: 17.303 iter/sec, elapsed: 30.0 sec
# Count: 490/2500, time remaining: 114.0 sec, rate average: 17.625 iter/sec, elapsed: 30.5 sec
# Count: 500/2500, time remaining: 115.6 sec, rate average: 17.301 iter/sec, elapsed: 31.1 sec
# Count: 510/2500, time remaining: 114.6 sec, rate average: 17.364 iter/sec, elapsed: 31.7 sec
# Count: 520/2500, time remaining: 114.3 sec, rate average: 17.320 iter/sec, elapsed: 32.3 sec
# Count: 530/2500, time remaining: 114.4 sec, rate average: 17.222 iter/sec, elapsed: 32.9 sec
# Count: 540/2500, time remaining: 111.7 sec, rate average: 17.554 iter/sec, elapsed: 33.4 sec
# Count: 550/2500, time remaining: 111.4 sec, rate average: 17.506 iter/sec, elapsed: 34.0 sec
# Count: 560/2500, time remaining: 108.8 sec, rate average: 17.831 iter/sec, elapsed: 34.5 sec
# Count: 570/2500, time remaining: 110.1 sec, rate average: 17.529 iter/sec, elapsed: 35.1 sec
# Count: 580/2500, time remaining: 109.1 sec, rate average: 17.592 iter/sec, elapsed: 35.7 sec
# Count: 590/2500, time remaining: 106.7 sec, rate average: 17.901 iter/sec, elapsed: 36.2 sec
# Count: 600/2500, time remaining: 107.2 sec, rate average: 17.730 iter/sec, elapsed: 36.8 sec
# Count: 610/2500, time remaining: 105.5 sec, rate average: 17.920 iter/sec, elapsed: 37.4 sec
# Count: 620/2500, time remaining: 105.5 sec, rate average: 17.816 iter/sec, elapsed: 37.9 sec
# Count: 630/2500, time remaining: 104.2 sec, rate average: 17.953 iter/sec, elapsed: 38.5 sec
# Count: 640/2500, time remaining: 105.2 sec, rate average: 17.685 iter/sec, elapsed: 39.1 sec
# Count: 650/2500, time remaining: 102.7 sec, rate average: 18.007 iter/sec, elapsed: 39.6 sec
# Count: 660/2500, time remaining: 105.5 sec, rate average: 17.448 iter/sec, elapsed: 40.2 sec
# Count: 670/2500, time remaining: 102.8 sec, rate average: 17.805 iter/sec, elapsed: 40.7 sec
# Count: 680/2500, time remaining: 101.2 sec, rate average: 17.987 iter/sec, elapsed: 41.3 sec
# Count: 690/2500, time remaining: 101.7 sec, rate average: 17.797 iter/sec, elapsed: 41.9 sec
# Count: 700/2500, time remaining: 99.9 sec, rate average: 18.012 iter/sec, elapsed: 42.4 sec
# Count: 710/2500, time remaining: 101.0 sec, rate average: 17.729 iter/sec, elapsed: 43.0 sec
# Count: 720/2500, time remaining: 100.0 sec, rate average: 17.797 iter/sec, elapsed: 43.5 sec
# Count: 730/2500, time remaining: 100.6 sec, rate average: 17.587 iter/sec, elapsed: 44.1 sec
# Count: 740/2500, time remaining: 98.0 sec, rate average: 17.957 iter/sec, elapsed: 44.7 sec
# Count: 750/2500, time remaining: 96.8 sec, rate average: 18.085 iter/sec, elapsed: 45.2 sec
# Count: 760/2500, time remaining: 107.9 sec, rate average: 16.121 iter/sec, elapsed: 45.9 sec
# Count: 770/2500, time remaining: 101.9 sec, rate average: 16.973 iter/sec, elapsed: 46.5 sec
# Count: 780/2500, time remaining: 98.6 sec, rate average: 17.437 iter/sec, elapsed: 47.0 sec
# Count: 790/2500, time remaining: 97.3 sec, rate average: 17.569 iter/sec, elapsed: 47.6 sec
# Count: 800/2500, time remaining: 95.7 sec, rate average: 17.764 iter/sec, elapsed: 48.1 sec
# Count: 810/2500, time remaining: 95.6 sec, rate average: 17.674 iter/sec, elapsed: 48.7 sec
# Count: 820/2500, time remaining: 93.7 sec, rate average: 17.931 iter/sec, elapsed: 49.3 sec
# Count: 830/2500, time remaining: 94.8 sec, rate average: 17.608 iter/sec, elapsed: 49.8 sec
# Count: 840/2500, time remaining: 92.5 sec, rate average: 17.950 iter/sec, elapsed: 50.4 sec
# Count: 850/2500, time remaining: 94.7 sec, rate average: 17.419 iter/sec, elapsed: 51.0 sec
# Count: 860/2500, time remaining: 93.2 sec, rate average: 17.596 iter/sec, elapsed: 51.5 sec
# Count: 870/2500, time remaining: 92.7 sec, rate average: 17.588 iter/sec, elapsed: 52.1 sec
# Count: 880/2500, time remaining: 92.2 sec, rate average: 17.568 iter/sec, elapsed: 52.7 sec
# Count: 890/2500, time remaining: 90.6 sec, rate average: 17.765 iter/sec, elapsed: 53.2 sec
# Count: 900/2500, time remaining: 92.0 sec, rate average: 17.389 iter/sec, elapsed: 53.8 sec
# Count: 910/2500, time remaining: 89.5 sec, rate average: 17.770 iter/sec, elapsed: 54.4 sec
# Count: 920/2500, time remaining: 95.4 sec, rate average: 16.557 iter/sec, elapsed: 55.0 sec
# Count: 930/2500, time remaining: 99.4 sec, rate average: 15.797 iter/sec, elapsed: 55.7 sec
# Count: 940/2500, time remaining: 103.1 sec, rate average: 15.130 iter/sec, elapsed: 56.4 sec
# Count: 950/2500, time remaining: 104.1 sec, rate average: 14.896 iter/sec, elapsed: 57.1 sec
# Count: 960/2500, time remaining: 105.2 sec, rate average: 14.639 iter/sec, elapsed: 57.8 sec
# Count: 970/2500, time remaining: 107.1 sec, rate average: 14.290 iter/sec, elapsed: 58.5 sec
# Count: 980/2500, time remaining: 101.2 sec, rate average: 15.016 iter/sec, elapsed: 59.1 sec
# Count: 990/2500, time remaining: 97.5 sec, rate average: 15.487 iter/sec, elapsed: 59.7 sec
# Count: 1000/2500, time remaining: 93.0 sec, rate average: 16.127 iter/sec, elapsed: 60.3 sec
# Count: 1010/2500, time remaining: 90.6 sec, rate average: 16.442 iter/sec, elapsed: 60.9 sec
# Count: 1020/2500, time remaining: 90.1 sec, rate average: 16.418 iter/sec, elapsed: 61.5 sec
# Count: 1030/2500, time remaining: 93.0 sec, rate average: 15.809 iter/sec, elapsed: 62.2 sec
# Count: 1040/2500, time remaining: 91.4 sec, rate average: 15.975 iter/sec, elapsed: 62.8 sec
# Count: 1050/2500, time remaining: 87.1 sec, rate average: 16.640 iter/sec, elapsed: 63.4 sec
# Count: 1060/2500, time remaining: 86.2 sec, rate average: 16.713 iter/sec, elapsed: 64.0 sec
# Count: 1070/2500, time remaining: 84.5 sec, rate average: 16.932 iter/sec, elapsed: 64.5 sec
# Count: 1080/2500, time remaining: 84.8 sec, rate average: 16.747 iter/sec, elapsed: 65.1 sec
# Count: 1090/2500, time remaining: 81.9 sec, rate average: 17.207 iter/sec, elapsed: 65.7 sec
# Count: 1100/2500, time remaining: 79.3 sec, rate average: 17.665 iter/sec, elapsed: 66.2 sec
# Count: 1110/2500, time remaining: 79.6 sec, rate average: 17.472 iter/sec, elapsed: 66.8 sec
# Count: 1120/2500, time remaining: 78.0 sec, rate average: 17.702 iter/sec, elapsed: 67.4 sec
# Count: 1130/2500, time remaining: 78.8 sec, rate average: 17.377 iter/sec, elapsed: 68.0 sec
# Count: 1140/2500, time remaining: 76.5 sec, rate average: 17.783 iter/sec, elapsed: 68.5 sec
# Count: 1150/2500, time remaining: 77.2 sec, rate average: 17.481 iter/sec, elapsed: 69.1 sec
# Count: 1160/2500, time remaining: 75.6 sec, rate average: 17.735 iter/sec, elapsed: 69.6 sec
# Count: 1170/2500, time remaining: 74.1 sec, rate average: 17.957 iter/sec, elapsed: 70.2 sec
# Count: 1180/2500, time remaining: 74.1 sec, rate average: 17.821 iter/sec, elapsed: 70.8 sec
# Count: 1190/2500, time remaining: 72.9 sec, rate average: 17.964 iter/sec, elapsed: 71.3 sec
# Count: 1200/2500, time remaining: 73.5 sec, rate average: 17.690 iter/sec, elapsed: 71.9 sec
# Count: 1210/2500, time remaining: 71.9 sec, rate average: 17.933 iter/sec, elapsed: 72.4 sec
# Count: 1220/2500, time remaining: 75.9 sec, rate average: 16.866 iter/sec, elapsed: 73.1 sec
# Count: 1230/2500, time remaining: 77.5 sec, rate average: 16.387 iter/sec, elapsed: 73.7 sec
# Count: 1240/2500, time remaining: 73.4 sec, rate average: 17.165 iter/sec, elapsed: 74.3 sec
# Count: 1250/2500, time remaining: 72.8 sec, rate average: 17.179 iter/sec, elapsed: 74.9 sec
# Count: 1260/2500, time remaining: 69.9 sec, rate average: 17.738 iter/sec, elapsed: 75.4 sec
# Count: 1270/2500, time remaining: 70.2 sec, rate average: 17.524 iter/sec, elapsed: 76.0 sec
# Count: 1280/2500, time remaining: 68.4 sec, rate average: 17.843 iter/sec, elapsed: 76.5 sec
# Count: 1290/2500, time remaining: 68.0 sec, rate average: 17.796 iter/sec, elapsed: 77.1 sec
# Count: 1300/2500, time remaining: 67.5 sec, rate average: 17.767 iter/sec, elapsed: 77.6 sec
# Count: 1310/2500, time remaining: 66.4 sec, rate average: 17.929 iter/sec, elapsed: 78.2 sec
# Count: 1320/2500, time remaining: 68.0 sec, rate average: 17.345 iter/sec, elapsed: 78.8 sec
# Count: 1330/2500, time remaining: 65.9 sec, rate average: 17.766 iter/sec, elapsed: 79.3 sec
# Count: 1340/2500, time remaining: 65.8 sec, rate average: 17.627 iter/sec, elapsed: 79.9 sec
# Count: 1350/2500, time remaining: 64.8 sec, rate average: 17.734 iter/sec, elapsed: 80.5 sec
# Count: 1360/2500, time remaining: 63.7 sec, rate average: 17.891 iter/sec, elapsed: 81.0 sec
# Count: 1370/2500, time remaining: 63.5 sec, rate average: 17.787 iter/sec, elapsed: 81.6 sec
# Count: 1380/2500, time remaining: 62.2 sec, rate average: 18.017 iter/sec, elapsed: 82.1 sec
# Count: 1390/2500, time remaining: 62.4 sec, rate average: 17.793 iter/sec, elapsed: 82.7 sec
# Count: 1400/2500, time remaining: 61.9 sec, rate average: 17.757 iter/sec, elapsed: 83.3 sec
# Count: 1410/2500, time remaining: 61.7 sec, rate average: 17.655 iter/sec, elapsed: 83.8 sec
# Count: 1420/2500, time remaining: 60.1 sec, rate average: 17.965 iter/sec, elapsed: 84.4 sec
# Count: 1430/2500, time remaining: 59.8 sec, rate average: 17.883 iter/sec, elapsed: 84.9 sec
# Count: 1440/2500, time remaining: 59.6 sec, rate average: 17.800 iter/sec, elapsed: 85.5 sec
# Count: 1450/2500, time remaining: 58.7 sec, rate average: 17.903 iter/sec, elapsed: 86.1 sec
# Count: 1460/2500, time remaining: 58.4 sec, rate average: 17.813 iter/sec, elapsed: 86.6 sec
# Count: 1470/2500, time remaining: 57.3 sec, rate average: 17.984 iter/sec, elapsed: 87.2 sec
# Count: 1480/2500, time remaining: 57.5 sec, rate average: 17.729 iter/sec, elapsed: 87.8 sec
# Count: 1490/2500, time remaining: 56.2 sec, rate average: 17.973 iter/sec, elapsed: 88.3 sec
# Count: 1500/2500, time remaining: 56.9 sec, rate average: 17.586 iter/sec, elapsed: 88.9 sec
# Count: 1510/2500, time remaining: 55.6 sec, rate average: 17.810 iter/sec, elapsed: 89.4 sec
# Count: 1520/2500, time remaining: 54.8 sec, rate average: 17.897 iter/sec, elapsed: 90.0 sec
# Count: 1530/2500, time remaining: 54.7 sec, rate average: 17.739 iter/sec, elapsed: 90.6 sec
# Count: 1540/2500, time remaining: 53.3 sec, rate average: 18.000 iter/sec, elapsed: 91.1 sec
# Count: 1550/2500, time remaining: 53.6 sec, rate average: 17.708 iter/sec, elapsed: 91.7 sec
# Count: 1560/2500, time remaining: 52.3 sec, rate average: 17.966 iter/sec, elapsed: 92.2 sec
# Count: 1570/2500, time remaining: 52.6 sec, rate average: 17.692 iter/sec, elapsed: 92.8 sec
# Count: 1580/2500, time remaining: 51.5 sec, rate average: 17.875 iter/sec, elapsed: 93.4 sec
# Count: 1590/2500, time remaining: 51.0 sec, rate average: 17.838 iter/sec, elapsed: 93.9 sec
# Count: 1600/2500, time remaining: 50.3 sec, rate average: 17.888 iter/sec, elapsed: 94.5 sec
# Count: 1610/2500, time remaining: 49.2 sec, rate average: 18.072 iter/sec, elapsed: 95.0 sec
# Count: 1620/2500, time remaining: 49.2 sec, rate average: 17.874 iter/sec, elapsed: 95.6 sec
# Count: 1630/2500, time remaining: 48.1 sec, rate average: 18.091 iter/sec, elapsed: 96.1 sec
# Count: 1640/2500, time remaining: 48.4 sec, rate average: 17.780 iter/sec, elapsed: 96.7 sec
# Count: 1650/2500, time remaining: 47.2 sec, rate average: 17.996 iter/sec, elapsed: 97.3 sec
# Count: 1660/2500, time remaining: 47.4 sec, rate average: 17.729 iter/sec, elapsed: 97.8 sec
# Count: 1670/2500, time remaining: 46.2 sec, rate average: 17.983 iter/sec, elapsed: 98.4 sec
# Count: 1680/2500, time remaining: 46.5 sec, rate average: 17.653 iter/sec, elapsed: 99.0 sec
# Count: 1690/2500, time remaining: 58.7 sec, rate average: 13.791 iter/sec, elapsed: 99.9 sec
# Count: 1700/2500, time remaining: 62.1 sec, rate average: 12.873 iter/sec, elapsed: 100.8 sec
# Count: 1710/2500, time remaining: 55.8 sec, rate average: 14.161 iter/sec, elapsed: 101.4 sec
# Count: 1720/2500, time remaining: 51.9 sec, rate average: 15.021 iter/sec, elapsed: 102.0 sec
# Count: 1730/2500, time remaining: 49.6 sec, rate average: 15.537 iter/sec, elapsed: 102.6 sec
# Count: 1740/2500, time remaining: 48.0 sec, rate average: 15.834 iter/sec, elapsed: 103.2 sec
# Count: 1750/2500, time remaining: 45.6 sec, rate average: 16.453 iter/sec, elapsed: 103.8 sec
# Count: 1760/2500, time remaining: 45.5 sec, rate average: 16.248 iter/sec, elapsed: 104.4 sec
# Count: 1770/2500, time remaining: 44.1 sec, rate average: 16.555 iter/sec, elapsed: 105.0 sec
# Count: 1780/2500, time remaining: 42.8 sec, rate average: 16.827 iter/sec, elapsed: 105.6 sec
# Count: 1790/2500, time remaining: 42.4 sec, rate average: 16.745 iter/sec, elapsed: 106.2 sec
# Count: 1800/2500, time remaining: 41.6 sec, rate average: 16.811 iter/sec, elapsed: 106.8 sec
# Count: 1810/2500, time remaining: 41.7 sec, rate average: 16.533 iter/sec, elapsed: 107.4 sec
# Count: 1820/2500, time remaining: 40.7 sec, rate average: 16.699 iter/sec, elapsed: 108.0 sec
# Count: 1830/2500, time remaining: 40.6 sec, rate average: 16.493 iter/sec, elapsed: 108.6 sec
# Count: 1840/2500, time remaining: 39.7 sec, rate average: 16.614 iter/sec, elapsed: 109.2 sec
# Count: 1850/2500, time remaining: 39.7 sec, rate average: 16.354 iter/sec, elapsed: 109.8 sec
# Count: 1860/2500, time remaining: 38.2 sec, rate average: 16.760 iter/sec, elapsed: 110.4 sec
# Count: 1870/2500, time remaining: 37.3 sec, rate average: 16.891 iter/sec, elapsed: 111.0 sec
# Count: 1880/2500, time remaining: 37.3 sec, rate average: 16.627 iter/sec, elapsed: 111.6 sec
# Count: 1890/2500, time remaining: 36.0 sec, rate average: 16.927 iter/sec, elapsed: 112.2 sec
# Count: 1900/2500, time remaining: 35.9 sec, rate average: 16.726 iter/sec, elapsed: 112.8 sec
# Count: 1910/2500, time remaining: 35.0 sec, rate average: 16.853 iter/sec, elapsed: 113.3 sec
# Count: 1920/2500, time remaining: 34.8 sec, rate average: 16.675 iter/sec, elapsed: 114.0 sec
# Count: 1930/2500, time remaining: 34.1 sec, rate average: 16.731 iter/sec, elapsed: 114.6 sec
# Count: 1940/2500, time remaining: 33.1 sec, rate average: 16.935 iter/sec, elapsed: 115.1 sec
# Count: 1950/2500, time remaining: 32.6 sec, rate average: 16.868 iter/sec, elapsed: 115.7 sec
# Count: 1960/2500, time remaining: 31.8 sec, rate average: 16.961 iter/sec, elapsed: 116.3 sec
# Count: 1970/2500, time remaining: 31.5 sec, rate average: 16.810 iter/sec, elapsed: 116.9 sec
# Count: 1980/2500, time remaining: 30.9 sec, rate average: 16.852 iter/sec, elapsed: 117.5 sec
# Count: 1990/2500, time remaining: 30.7 sec, rate average: 16.625 iter/sec, elapsed: 118.1 sec
# Count: 2000/2500, time remaining: 29.4 sec, rate average: 17.016 iter/sec, elapsed: 118.7 sec
# Count: 2010/2500, time remaining: 29.5 sec, rate average: 16.630 iter/sec, elapsed: 119.3 sec
# Count: 2020/2500, time remaining: 28.5 sec, rate average: 16.852 iter/sec, elapsed: 119.9 sec
# Count: 2030/2500, time remaining: 27.6 sec, rate average: 17.039 iter/sec, elapsed: 120.5 sec
# Count: 2040/2500, time remaining: 27.3 sec, rate average: 16.871 iter/sec, elapsed: 121.1 sec
# Count: 2050/2500, time remaining: 26.7 sec, rate average: 16.827 iter/sec, elapsed: 121.7 sec
# Count: 2060/2500, time remaining: 26.8 sec, rate average: 16.441 iter/sec, elapsed: 122.3 sec
# Count: 2070/2500, time remaining: 25.8 sec, rate average: 16.658 iter/sec, elapsed: 122.9 sec
# Count: 2080/2500, time remaining: 25.6 sec, rate average: 16.417 iter/sec, elapsed: 123.5 sec
# Count: 2090/2500, time remaining: 24.5 sec, rate average: 16.755 iter/sec, elapsed: 124.1 sec
# Count: 2100/2500, time remaining: 23.6 sec, rate average: 16.936 iter/sec, elapsed: 124.7 sec
# Count: 2110/2500, time remaining: 23.4 sec, rate average: 16.689 iter/sec, elapsed: 125.3 sec
# Count: 2120/2500, time remaining: 22.3 sec, rate average: 17.029 iter/sec, elapsed: 125.9 sec
# Count: 2130/2500, time remaining: 22.2 sec, rate average: 16.686 iter/sec, elapsed: 126.5 sec
# Count: 2140/2500, time remaining: 21.5 sec, rate average: 16.725 iter/sec, elapsed: 127.1 sec
# Count: 2150/2500, time remaining: 21.9 sec, rate average: 15.984 iter/sec, elapsed: 127.7 sec
# Count: 2160/2500, time remaining: 22.0 sec, rate average: 15.479 iter/sec, elapsed: 128.4 sec
# Count: 2170/2500, time remaining: 20.5 sec, rate average: 16.079 iter/sec, elapsed: 129.0 sec
# Count: 2180/2500, time remaining: 19.9 sec, rate average: 16.043 iter/sec, elapsed: 129.6 sec
# Count: 2190/2500, time remaining: 18.9 sec, rate average: 16.438 iter/sec, elapsed: 130.2 sec
# Count: 2200/2500, time remaining: 18.0 sec, rate average: 16.682 iter/sec, elapsed: 130.8 sec
# Count: 2210/2500, time remaining: 17.6 sec, rate average: 16.489 iter/sec, elapsed: 131.4 sec
# Count: 2220/2500, time remaining: 16.7 sec, rate average: 16.783 iter/sec, elapsed: 132.0 sec
# Count: 2230/2500, time remaining: 16.2 sec, rate average: 16.641 iter/sec, elapsed: 132.6 sec
# Count: 2240/2500, time remaining: 15.4 sec, rate average: 16.932 iter/sec, elapsed: 133.2 sec
# Count: 2250/2500, time remaining: 14.9 sec, rate average: 16.733 iter/sec, elapsed: 133.8 sec
# Count: 2260/2500, time remaining: 14.2 sec, rate average: 16.843 iter/sec, elapsed: 134.4 sec
# Count: 2270/2500, time remaining: 13.8 sec, rate average: 16.650 iter/sec, elapsed: 135.0 sec
# Count: 2280/2500, time remaining: 13.1 sec, rate average: 16.770 iter/sec, elapsed: 135.6 sec
# Count: 2290/2500, time remaining: 12.4 sec, rate average: 16.880 iter/sec, elapsed: 136.2 sec
# Count: 2300/2500, time remaining: 12.0 sec, rate average: 16.629 iter/sec, elapsed: 136.8 sec
# Count: 2310/2500, time remaining: 11.2 sec, rate average: 17.014 iter/sec, elapsed: 137.3 sec
# Count: 2320/2500, time remaining: 10.8 sec, rate average: 16.688 iter/sec, elapsed: 138.0 sec
# Count: 2330/2500, time remaining: 10.2 sec, rate average: 16.681 iter/sec, elapsed: 138.6 sec
# Count: 2340/2500, time remaining: 9.7 sec, rate average: 16.420 iter/sec, elapsed: 139.2 sec
# Count: 2350/2500, time remaining: 8.9 sec, rate average: 16.826 iter/sec, elapsed: 139.8 sec
# Count: 2360/2500, time remaining: 8.2 sec, rate average: 17.045 iter/sec, elapsed: 140.3 sec
# Count: 2370/2500, time remaining: 7.7 sec, rate average: 16.801 iter/sec, elapsed: 140.9 sec
# Count: 2380/2500, time remaining: 7.1 sec, rate average: 16.931 iter/sec, elapsed: 141.5 sec
# Count: 2390/2500, time remaining: 6.6 sec, rate average: 16.770 iter/sec, elapsed: 142.1 sec
# Count: 2400/2500, time remaining: 5.9 sec, rate average: 16.930 iter/sec, elapsed: 142.7 sec
# Count: 2410/2500, time remaining: 5.4 sec, rate average: 16.636 iter/sec, elapsed: 143.3 sec
# Count: 2420/2500, time remaining: 4.8 sec, rate average: 16.718 iter/sec, elapsed: 143.9 sec
# Count: 2430/2500, time remaining: 4.4 sec, rate average: 16.074 iter/sec, elapsed: 144.6 sec
# Count: 2440/2500, time remaining: 3.6 sec, rate average: 16.607 iter/sec, elapsed: 145.1 sec
# Count: 2450/2500, time remaining: 3.0 sec, rate average: 16.894 iter/sec, elapsed: 145.7 sec
# Count: 2460/2500, time remaining: 2.4 sec, rate average: 16.541 iter/sec, elapsed: 146.4 sec
# Count: 2470/2500, time remaining: 1.8 sec, rate average: 16.246 iter/sec, elapsed: 147.0 sec
# Count: 2480/2500, time remaining: 1.2 sec, rate average: 16.126 iter/sec, elapsed: 147.6 sec
# Count: 2490/2500, time remaining: 0.6 sec, rate average: 16.524 iter/sec, elapsed: 148.2 sec
# Count: 2500/2500, time remaining: 0.0 sec, rate average: 16.382 iter/sec, elapsed: 148.8 sec

# %%
mach_samples = mach_ret
cos_AoA_x = cos_x_ret
cos_AoA_y = cos_y_ret
cos_AoA_z = cos_z_ret
C_A = CA_ret
C_Ny = CNy_ret
C_Nz = CNz_ret
M_max = max_M

# %% [markdown]
# ### Compute AoAs and Aerodynamic Coefficients ###

# %%
eBx = ksp2pyoptflight(eby)[0]
eBy = np.cross([0, 0, 1], eBx)
eBz = np.cross(eBx, eBy)
vel_dir_samples = ksp2pyoptflight(vel_dir_samples)
force_samples = ksp2pyoptflight(force_samples)
vrel_mag = mach_samples*a
FBx = force_samples @ eBx # dot product (vector projection)
FBy = force_samples @ eBy # dot product (vector projection)
FBz = force_samples @ eBz # dot product (vector projection)
C_A = FBx/(0.5*rho*vrel_mag**2*A_ref)
C_Ny = FBy/(0.5*rho*vrel_mag**2*A_ref)
C_Nz = FBz/(0.5*rho*vrel_mag**2*A_ref)
cos_AoA_x = vel_dir_samples @ eBx # dot product (cos law)
cos_AoA_y = vel_dir_samples @ eBy # dot product (cos law)
cos_AoA_z = vel_dir_samples @ eBz # dot product (cos law)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 4
#       2 eBy = np.cross([0, 0, 1], eBx)
#       3 eBz = np.cross(eBx, eBy)
# ----> 4 vel_dir_samples = ksp2pyoptflight(vel_dir_samples)
#       5 force_samples = ksp2pyoptflight(force_samples)
#       6 vrel_mag = mach_samples*a
#
# NameError: name 'vel_dir_samples' is not defined

# %% [markdown]
# ### Save Data To Avoid Doing This Again

# %%
filename = 'flight_data/pyoptflight_stage_2'
with open(filename + '.json', 'w') as json_file:
    # Convert numpy arrays to lists for JSON serialization
    json_data = {'mach_samples': mach_samples.tolist(),
                 'cos_AoA_x': cos_AoA_x.tolist(),
                 'cos_AoA_y': cos_AoA_y.tolist(),
                 'cos_AoA_z': cos_AoA_z.tolist(),
                 'C_A': C_A.tolist(),
                 'C_Ny': C_Ny.tolist(),
                 'C_Nz': C_Nz.tolist(),
                 'M_max': M_max}
    # json.dump(json_data, json_file, indent=4) # Pretty printing if it needs to be uber human readable
    json.dump(json_data, json_file)
print(f"Recording saved to {filename}.json")
# Out:
# Recording saved to flight_data/pyoptflight_stage_2.json

# %% [markdown]
# ### Function to Plot Data ###

# %%
def plot_data(data: list[tuple[np.ndarray]] | tuple[np.ndarray],
              axis_titles: list[str],
              title: str = None,
              x_scale: str ='linear',
              y_scale: str ='linear',
              scatter: list[bool] | bool = True,
              surface: list[bool] | bool = False,
              opacity: list[float] | float = 0.5,
              marker_size: list[int] | int = 2,
              fig=None):
            
    # Ensure data_list is a list of (x, y, z) tuples
    data_list = data if isinstance(data, list) else [data]
    n = len(data_list)

    # Helper to broadcast scalar parameters to lists
    def _broadcast(val, name: str):
        if isinstance(val, list):
            if len(val) != n:
                raise ValueError(f"Length of '{name}' list ({len(val)}) must match number of datasets ({n}).")
            return val
        else:
            return [val] * n

    scatter_list = _broadcast(scatter, 'scatter')
    surface_list = _broadcast(surface, 'surface')
    opacity_list = _broadcast(opacity, 'opacity')
    marker_size_list = _broadcast(marker_size, 'marker_size')

    # Create new figure if none provided
    if fig is None:
        fig = go.Figure()

    # Plot each dataset
    for idx, (x, y, z) in enumerate(data_list):
        name_prefix = f"data_{idx}"
        # Scatter points
        if scatter_list[idx]:
            fig.add_trace(go.Scatter3d(
                x=x, y=y, z=z,
                mode='markers',
                marker=dict(size=marker_size_list[idx], opacity=opacity_list[idx]),
                name=f"{name_prefix}_scatter"
            ))

        # Surface mesh via Delaunay triangulation
        if surface_list[idx]:
            # Apply log transform for triangulation if needed
            if x_scale == 'log':
                xt = np.log10(x)
            else:
                xt = np.array(x, copy=False)
            if y_scale == 'log':
                yt = np.log10(y)
            else:
                yt = np.array(y, copy=False)

            pts2d = np.column_stack((xt, yt))
            tri = Delaunay(pts2d)
            simplices = tri.simplices

            fig.add_trace(go.Mesh3d(
                x=x, y=y, z=z,
                i=simplices[:, 0],
                j=simplices[:, 1],
                k=simplices[:, 2],
                opacity=opacity_list[idx],
                flatshading=True,
                showscale=False,
                name=f"{name_prefix}_surface"
            ))

    # Unpack axis titles
    if len(axis_titles) != 3:
        raise ValueError("axis_titles must be a list of three strings [x_title, y_title, z_title].")
    x_axis, y_axis, z_axis = axis_titles

    # Finalize layout
    fig.update_layout(
        title=title,
        scene=dict(
            xaxis=dict(title=x_axis, type=x_scale),
            yaxis=dict(title=y_axis, type=y_scale),
            zaxis=dict(title=z_axis)
        ),
        height=800,
        width=800
    )

    fig.show()

# %% [markdown]
# ### Plot of Results ###

# %%
mach_data = mach_samples
# mach_data = np.tanh((mach_samples - 1)/6)
plot_data((cos_AoA_x, mach_data, C_A) , ['cos(AoA)_x', 'Mach', 'C_A'],  y_scale='linear', surface=True, scatter=True, opacity=0.1)
plot_data((cos_AoA_y, mach_data, C_Ny), ['cos(AoA)_y', 'Mach', 'C_Ny'], y_scale='linear', surface=True, scatter=True, opacity=0.1)
plot_data((cos_AoA_z, mach_data, C_Nz), ['cos(AoA)_z', 'Mach', 'C_Nz'], y_scale='linear', surface=True, scatter=True, opacity=0.1)

# %% [markdown]
# ## Legendre Polynomial Interpretation ##
# ### Theory ###
# We want to approximate a function
# $$
# C_x = f(M, \cos{(\alpha)})
# $$
# from a large number of sample points (nsamples) $(M_i, \cos{(\alpha_i)}, C_{x, i})$ with minimal computations and stored interpolating coefficients.
#
# We can approximate the function using the Legendre Polynomial Basis:
# $$
# f(M, \cos{\alpha}) \approx \sum^{n_M}_{i=0}\sum^{n_A}_{i=0}a_{ij}P_i(\tilde{M})P_j(\tilde{A})
# $$
# where $P_k(x)$ is the Legendre polynomial of degree $k$, $\tilde{M}$ and $\tilde{A}$ are scaled inputs to our function, and $a_{ij}$ are the coefficients we want to solve for that will approximate our problem. The degree of our approximation is $n_M$ and $n_A$ in the Mach and Angle of Attack dimensions respectively. The total number of coefficients $a_{ij}$ will be $(n_M+1)(n_A+1)$.
#
# The Legendre Polynomial Basis is a an othogonal set which is numerically stable. This is a better choice than a monomial basis interpolation because legendre basis avoid a certain redundancy or correlation between basis terms. The Legendre polynomials can be computed via the recurrence relation:
# $$
# P_{n+1}(x) = \frac{(2n+1)xP_n(x) - nP_{n-1}(x)}{n+1}
# $$
#
# We can formulate our problem by constructing the pseudo-Vandermonde matrix $V$ where each row corresponds to a sample point of our data and each column corresponds to a term of our Legendre polynomial products $P_i(\tilde{M})P_j(\tilde{A})$. Thus $V$ will have shape $(\text{nsamples, }(n_M+1)(n_A+1))$. We then can solve the least squares problem of the form $Va \approx Y$ where $Y$ is our $C_{x,i}$ data and $a$ is the set of coefficients we are solving for.

# %% [markdown]
# ### Legendre Polynomial Function ###

# %%
def legendre_polynomials(x, degree):
    P = [1, x]  # P0 and P1
    for n in range(1, degree):
        Pn = ((2*n + 1) * x * P[n] - n * P[n - 1]) / (n + 1)
        P.append(Pn)
    return P  # P[0] through P[degree]

# %% [markdown]
# ### Evaluate Interpolation ###

# %%
def rescale(x, x_min, x_max): # Compresses data into a range [-1, 1] where the legendre polynomial are orthogonal
    return 2*(x-x_min)/(x_max-x_min) - 1 

def evaluate_interpolation(x, y, a, x_deg, y_deg, x_min, x_max, y_min, y_max):
    xs = rescale(x, x_min, x_max)
    ys = rescale(y, y_min, y_max)

    a = np.reshape(a, (x_deg+1, y_deg+1))
    Px = legendre_polynomials(xs, x_deg)
    Py = legendre_polynomials(ys, y_deg)
    z_interp = 0
    for i in range(x_deg+1):
        for j in range(y_deg+1):
            z_interp += a[i][j]*Px[i]*Py[j]
    return z_interp

# %% [markdown]
# ### Interpolate Data ###

# %%
def pre_skew(data):
    return data
    # return np.tanh((data - 1)/4)

def legendre_interpolation(x_data, y_data, z_data, x_min, x_max, y_min, y_max, x_deg, y_deg):
    xs = rescale(x_data, x_min, x_max)
    ys = rescale(y_data, y_min, y_max)

    # pseudo-vandermonde matrix with columns of xs then columns of ys ?
    V = legvander2d(xs, ys, [x_deg, y_deg]).reshape(len(x_data), -1)

    # Solves Va = z_data, a will be in form of coefficients for xs then coefficients for ys ?
    a = np.linalg.lstsq(V, z_data, rcond=None)[0]

    z_interp = V@a
    r2 = r2_score(z_data, z_interp)
    print("R² =", r2)
    return a, r2

# %% [markdown]
# ### Generate Interpolating Coefficients ###

# %%
M_deg, A_deg = 20, 20
M_data = pre_skew(mach_samples)
ax, r2x = legendre_interpolation(M_data, cos_AoA_x, C_A,  0, M_max,  0, 1, M_deg, A_deg)
ay, r2y = legendre_interpolation(M_data, cos_AoA_y, C_Ny, 0, M_max, -1, 1, M_deg, A_deg)
az, r2z = legendre_interpolation(M_data, cos_AoA_z, C_Nz, 0, M_max, -1, 1, M_deg, A_deg)
# Out:
# R² = 0.9994051024897534
# R² = 0.9999683477582421
# R² = 0.9999682401241229

# %% [markdown]
# ### Generate and Plot Interpolated Surface ###

# %%
M_interp = np.linspace(0, M_max, 100)
A_interp_x = np.linspace(0, 1, 100)
A_interp_yz = np.linspace(-1, 1, 100)

Mx, Ax = np.meshgrid(M_interp, A_interp_x, indexing='ij')
Myz, Ayz = np.meshgrid(M_interp, A_interp_yz, indexing='ij')

C_A_interp = evaluate_interpolation(pre_skew(Mx), Ax, ax, M_deg, A_deg, 0, M_max, 0, 1)
C_Ny_interp = evaluate_interpolation(pre_skew(Myz), Ayz, ay, M_deg, A_deg, 0, M_max, -1, 1)
C_Nz_interp = evaluate_interpolation(pre_skew(Myz), Ayz, az, M_deg, A_deg, 0, M_max, -1, 1)

plot_data([(Ax.ravel(), Mx.ravel(), C_A_interp.ravel())   , (cos_AoA_x, mach_data, C_A) ], ['cos(AoA)_x', 'Mach', 'C_A'],  y_scale='linear', surface=[True, False], scatter=[False, True])
plot_data([(Ayz.ravel(), Myz.ravel(), C_Ny_interp.ravel()), (cos_AoA_y, mach_data, C_Ny)], ['cos(AoA)_y', 'Mach', 'C_Ny'], y_scale='linear', surface=[True, False], scatter=[False, True])
plot_data([(Ayz.ravel(), Myz.ravel(), C_Nz_interp.ravel()), (cos_AoA_z, mach_data, C_Nz)], ['cos(AoA)_z', 'Mach', 'C_Nz'], y_scale='linear', surface=[True, False], scatter=[False, True])

# %% [markdown]
# ### Plotting the Error ###

# %%
x_err = np.empty_like(C_A)
y_err = np.empty_like(C_Ny)
z_err = np.empty_like(C_Nz)
for i, (M, Ax, Ay, Az) in enumerate(zip(mach_samples, cos_AoA_x, cos_AoA_y, cos_AoA_z)):
    C_A_interp  = evaluate_interpolation(pre_skew(M), Ax, ax, M_deg, A_deg, 0, M_max,  0, 1)
    C_Ny_interp = evaluate_interpolation(pre_skew(M), Ay, ay, M_deg, A_deg, 0, M_max, -1, 1)
    C_Nz_interp = evaluate_interpolation(pre_skew(M), Az, az, M_deg, A_deg, 0, M_max, -1, 1)
    x_err[i] = C_A[i]  - C_A_interp
    y_err[i] = C_Ny[i] - C_Ny_interp
    z_err[i] = C_Nz[i] - C_Nz_interp

mach_data = mach_samples
plot_data((cos_AoA_x, mach_samples, x_err), ['cos(AoA)_x', 'Mach', 'x_err'], y_scale='linear', surface=False, scatter=True)
plot_data((cos_AoA_y, mach_samples, y_err), ['cos(AoA)_y', 'Mach', 'y_err'], y_scale='linear', surface=False, scatter=True)
plot_data((cos_AoA_z, mach_samples, z_err), ['cos(AoA)_z', 'Mach', 'z_err'], y_scale='linear', surface=False, scatter=True)

# %% [markdown]
# # Capture Data Live #
# ### Start Streams ###

# %%
# Need functions for calculating things not yet generalized above
# Want live plot of Mach vs arccos(cos(AoA)) for x, y, z
# Want drawing functions for body x, y, z basis vecs

stream_dict = {
    'ut': (getattr, conn.space_center, 'ut'),
    'position': (vessel.position, celest_refframe),
    'velocity': (vessel.velocity, celest_refframe),
    'direction': (vessel.direction, celest_refframe),
    'aerodynamic_force': (getattr, vessel.flight(celest_refframe), 'aerodynamic_force'),
    'mach': (getattr, vessel.flight(), 'mach'),
    'density': (getattr, vessel.flight(), 'atmosphere_density'),
    'altitude': (getattr, vessel.flight(), 'mean_altitude')
}
session = (conn, vessel, celest_refframe)
streams = ghf.start_streams(session, stream_dict = stream_dict)

# %% [markdown]
# ### Important Functions for Stuff ###

# %%
def py2ksp(vec):
    x = vec[0]
    y = vec[2]
    z = vec[1]
    return np.array([x, y, z])

def ksp2py(vec):
    x = vec[0]
    y = vec[2]
    z = vec[1]
    return np.array([x, y, z])

def simulate_aerodynamic_force(): # Returns in ksp global frame
    pos = streams['position']()
    vel = streams['velocity']()
    sim_aero = vessel.flight(celest_refframe).simulate_aerodynamic_force_at(kerbin, pos, vel)
    return np.array(sim_aero)

omega = np.array(kerbin.angular_velocity(celest_refframe))
def wind(): # Wind vector in ksp global frame
    R = np.array(streams['position']())
    wind = np.cross(omega, R)
    return wind

def vel_rel(): # Atmosphere relative velocity in ksp global frame
    return np.array(streams['velocity']()) - wind()

def eBx(): # Returns in pyoptflight global frame
    eby = streams['direction']()
    return ksp2py(eby)

def eBy(): # Returns in pyoptflight global frame
    return np.cross([0, 0, 1], eBx())

def eBz(): # Returns in pyoptflight global frame
    return np.cross(eBx(), eBy())

def mach_label():
    return round(streams['mach'](), 2)

def vel_dir(): # Relative velocity direction in pyoptflight global frame
    v = ksp2py(vel_rel())
    return v/np.linalg.norm(v)

def cos_AoA_x():
    return np.dot(vel_dir(), eBx())

def cos_AoA_y():
    return np.dot(vel_dir(), eBy())

def cos_AoA_z():
    return np.dot(vel_dir(), eBz())

def AoA_x():
    rad = np.arccos(max(min(cos_AoA_x(), 1), -1))
    return np.rad2deg(rad)

def AoA_y():
    rad = np.arccos(max(min(cos_AoA_y(), 1), -1))
    return np.rad2deg(rad)

def AoA_z():
    rad = np.arccos(max(min(cos_AoA_z(), 1), -1))
    return np.rad2deg(rad)

# %% [markdown]
# ### Start Drawing Stuff ###

# %%
drawer = ghf.VectorDrawer(session, streams, scale=1, normalize=True)
drawer.register_vector("Vel", vel_rel, normalize=True, scale=10, labels=mach_label)
drawer.register_vector("x", lambda: py2ksp(eBx()), normalize=True, scale=10, labels="x", colors=(1, 0, 0))
drawer.register_vector("y", lambda: py2ksp(eBy()), normalize=True, scale=10, labels="y", colors=(0, 1, 0))
drawer.register_vector("z", lambda: py2ksp(eBz()), normalize=True, scale=10, labels="z", colors=(0, 0, 1))
drawer.register_vector("F", lambda: np.array(streams['aerodynamic_force']()), normalize=True, scale=10, labels="F")
drawer.start_drawing(dt=0.01)

# %% [markdown]
# ### Recording Script To Collect Data ###

# %%
filename = 'flight_data/pyoptflight_stage_1_manual_1'

# %%
recorder = ghf.Recording(session, streams)
recorder.register_stream_func('eBx', eBx)
recorder.register_stream_func('eBy', eBy)
recorder.register_stream_func('eBz', eBz)
recorder.register_stream_func('vel_dir', vel_dir)
recorder.register_stream_func('cos_AoA_x', cos_AoA_x)
recorder.register_stream_func('cos_AoA_y', cos_AoA_y)
recorder.register_stream_func('cos_AoA_z', cos_AoA_z)
recorder.register_stream_func('AoA_x', AoA_x)
recorder.register_stream_func('AoA_y', AoA_y)
recorder.register_stream_func('AoA_z', AoA_z)
recorder.register_stream_func('vel_rel', vel_rel)
recorder.start_recording(dt=0.25)

# %% [markdown]
# ### Some Code For Live Feedback in Here ###

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
configs = [
    ('AoA_x', 0, 25, 0, 90),
    ('AoA_y', 0, 25, 0, 180),
    ('AoA_z', 0, 25, 0, 180),
]
scatters = []
for ax, (key, xmin, xmax, ymin, ymax) in zip(axes, configs):
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_xlabel('mach')
    ax.set_ylabel(key)
    # ax.set_title(f'mach vs {key}')
    scat = ax.scatter([], [], s=10)
    scatters.append((key, scat))
plt.tight_layout()

def update(_):
    data = recorder.snapshot()
    mach = np.array(data['mach'])
    artists = []
    for key, scat in scatters:
        y = np.array(data[key])
        scat.set_offsets(np.column_stack((mach, y)))
        artists.append(scat)
    return artists

ani = FuncAnimation(fig, update, interval=250, blit=True, cache_frame_data=False)

# %% [markdown]
# ### Stop and Save the Data ###

# %%
# recorder.stop_recording()
recorder.save_recording(filename=filename, format='json')

# %%
recorder.start_recording(dt=0.25)

# %%
drawer.stop_drawing()
ghf.stop_streams(streams)

# %% [markdown]
# # Load and Process Recorded Data #
# ### Load and Compute ###

# %%
A_ref = (1.25/2)**2*np.pi
M_max = 25

with open(filename+'.json', 'r') as f:
    data = json.load(f)

aero_F = ksp2pyoptflight(np.array(data['aerodynamic_force']))
mach = np.array(data['mach'])
vel = ksp2pyoptflight(np.array(data['velocity']))
pos = ksp2pyoptflight(np.array(data['position']))
omega = np.array([0, 0, 2.915709e-4])
wind = np.array([np.cross(omega, p) for p in pos])
vel_rel = vel - wind
rho = np.array(data['density'])

eBx = np.array(data['eBx'])
eBy = np.array(data['eBy'])
eBz = np.array(data['eBz'])
FBx = np.sum(aero_F * eBx, axis=1)
FBy = np.sum(aero_F * eBy, axis=1)
FBz = np.sum(aero_F * eBz, axis=1)

vmag2 = np.sum(vel_rel**2, axis=1)
C_A = FBx/(0.5*rho*vmag2*A_ref)
C_Ny = FBy/(0.5*rho*vmag2*A_ref)
C_Nz = FBz/(0.5*rho*vmag2*A_ref)

cos_AoA_x = np.array(data['cos_AoA_x'])
cos_AoA_y = np.array(data['cos_AoA_y'])
cos_AoA_z = np.array(data['cos_AoA_z'])

# %% [markdown]
# ### Plot Data ###

# %%
plot_data((cos_AoA_x, mach, C_A) , ['cos(AoA)_x', 'Mach', 'C_A'],  y_scale='linear', surface=True, scatter=True, opacity=0.1)
plot_data((cos_AoA_y, mach, C_Ny), ['cos(AoA)_y', 'Mach', 'C_Ny'], y_scale='linear', surface=True, scatter=True, opacity=0.1)
plot_data((cos_AoA_z, mach, C_Nz), ['cos(AoA)_z', 'Mach', 'C_Nz'], y_scale='linear', surface=True, scatter=True, opacity=0.1)

# %% [markdown]
# ### Generate Interpolating Coefficients ###

# %%
M_deg, A_deg = 20, 4
M_data = pre_skew(mach)
ax, r2x = legendre_interpolation(M_data, cos_AoA_x, C_A,  0, M_max,  0, 1, M_deg, A_deg)
ay, r2y = legendre_interpolation(M_data, cos_AoA_y, C_Ny, 0, M_max, -1, 1, M_deg, A_deg)
az, r2z = legendre_interpolation(M_data, cos_AoA_z, C_Nz, 0, M_max, -1, 1, M_deg, A_deg)

# %% [markdown]
# ### Generate and Plot Interpolated Surface ###

# %%
M_interp = np.linspace(0, M_max, 100)
A_interp_x = np.linspace(0, 1, 100)
A_interp_yz = np.linspace(-1, 1, 100)

Mx, Ax = np.meshgrid(M_interp, A_interp_x, indexing='ij')
Myz, Ayz = np.meshgrid(M_interp, A_interp_yz, indexing='ij')

C_A_interp = evaluate_interpolation(pre_skew(Mx), Ax, ax, M_deg, A_deg, 0, M_max, 0, 1)
C_Ny_interp = evaluate_interpolation(pre_skew(Myz), Ayz, ay, M_deg, A_deg, 0, M_max, -1, 1)
C_Nz_interp = evaluate_interpolation(pre_skew(Myz), Ayz, az, M_deg, A_deg, 0, M_max, -1, 1)

plot_data([(Ax.ravel(), Mx.ravel(), C_A_interp.ravel())   , (cos_AoA_x, mach, C_A) ], ['cos(AoA)_x', 'Mach', 'C_A'],  y_scale='linear', surface=[True, False], scatter=[False, True])
plot_data([(Ayz.ravel(), Myz.ravel(), C_Ny_interp.ravel()), (cos_AoA_y, mach, C_Ny)], ['cos(AoA)_y', 'Mach', 'C_Ny'], y_scale='linear', surface=[True, False], scatter=[False, True])
plot_data([(Ayz.ravel(), Myz.ravel(), C_Nz_interp.ravel()), (cos_AoA_z, mach, C_Nz)], ['cos(AoA)_z', 'Mach', 'C_Nz'], y_scale='linear', surface=[True, False], scatter=[False, True])

# %% [markdown]
# ### Plot the Error ###

# %%
x_err = np.empty_like(C_A)
y_err = np.empty_like(C_Ny)
z_err = np.empty_like(C_Nz)
for i, (M, Ax, Ay, Az) in enumerate(zip(mach, cos_AoA_x, cos_AoA_y, cos_AoA_z)):
    C_A_interp  = evaluate_interpolation(pre_skew(M), Ax, ax, M_deg, A_deg, 0, 25,  0, 1)
    C_Ny_interp = evaluate_interpolation(pre_skew(M), Ay, ay, M_deg, A_deg, 0, 25, -1, 1)
    C_Nz_interp = evaluate_interpolation(pre_skew(M), Az, az, M_deg, A_deg, 0, 25, -1, 1)
    x_err[i] = C_A[i]  - C_A_interp
    y_err[i] = C_Ny[i] - C_Ny_interp
    z_err[i] = C_Nz[i] - C_Nz_interp

mach_data = mach
plot_data((cos_AoA_x, mach, x_err), ['cos(AoA)_x', 'Mach', 'x_err'], y_scale='linear', surface=False, scatter=True)
plot_data((cos_AoA_y, mach, y_err), ['cos(AoA)_y', 'Mach', 'y_err'], y_scale='linear', surface=False, scatter=True)
plot_data((cos_AoA_z, mach, z_err), ['cos(AoA)_z', 'Mach', 'z_err'], y_scale='linear', surface=False, scatter=True)

# %% [markdown]
# ### Other methods below here vvv ###

# %%
# --- Synthetic data generation for demonstration ---
mach = mach_samples
cos_aoa = cos_AoA_x
# True underlying Cd with a transonic bump plus noise
Cd = C_A

M = mach
A = cos_aoa
Y = Cd
ns = len(M)

# 1) Baseline + bump decomposition
X_bas = np.vstack([np.ones(ns), M, A, M*A]).T
p, *_ = la.lstsq(X_bas, Y)
P = X_bas.dot(p)

# delta = 0.02
delta = 6
S = 0.5 * (np.tanh((M - 0.8) / delta) - np.tanh((M - 1.2) / delta))

X_bump = np.vstack([np.ones(ns), M - 1, A]).T
d, *_ = la.lstsq(S[:, None] * X_bump, Y - P)

Cd1 = P + S * (X_bump.dot(d))
r2_1 = r2_score(Y, Cd1)

# 2) Smooth‑blend of four regime polynomials
mus = np.array([0, 1, 3, 10])
sigmas = np.array([0.5, 0.1, 1, 5])
W_i = np.exp(-((M[:, None] - mus)**2) / (2 * sigmas**2))
W_i /= W_i.sum(axis=1, keepdims=True)

coeffs2 = []
Cd2 = np.zeros(ns)
for i in range(4):
    wi = W_i[:, i]
    p_i, *_ = la.lstsq((wi[:, None] * X_bas), wi * Y)
    coeffs2.append(p_i)
    Cd2 += wi * (X_bas.dot(p_i))
r2_2 = r2_score(Y, Cd2)

# 3) 2D Legendre expansion
M_s = 2 * (M - M.min()) / (M.max() - M.min()) - 1
A_s = 2 * (A - A.min()) / (A.max() - A.min()) - 1
deg_M, deg_A = 5, 3
V = legvander2d(M_s, A_s, [deg_M, deg_A])
V2 = V.reshape(ns, -1)
coeffs3, *_ = la.lstsq(V2, Y)
Cd3 = V2.dot(coeffs3)
r2_3 = r2_score(Y, Cd3)

# 4) Gaussian RBF
eps = 0.1
rbf = Rbf(M, A, Y, function='gaussian', epsilon=eps, smooth=1e-2)
Cd4 = rbf(M, A)
nodes = np.vstack(rbf.xi).T  # centers
weights = rbf.di            # weights
r2_4 = r2_score(Y, Cd4)

# --- Print results ---
print("=== 1) Baseline + bump ===")
print("Baseline coeffs p:", p)
print("Bump coeffs d:", d)
print("R² =", r2_1, "\n")

print("=== 2) Smooth‑blend regimes ===")
for i, p_i in enumerate(coeffs2):
    print(f"Regime {i} @ μ={mus[i]}: coeffs = {p_i}")
print("R² =", r2_2, "\n")

print("=== 3) Legendre expansion (deg_M=3, deg_A=3) ===")
print("Flattened coeffs:", coeffs3)
print("R² =", r2_3, "\n")

print("=== 4) Gaussian RBF (ε =", eps, ") ===")
print("Number of centers:", len(weights))
print("Example centers & weights (first 10):")
for i in range(min(10, len(weights))):
    print(f"  Center {i}: M={nodes[i,0]:.3f}, A={nodes[i,1]:.3f}, w={weights[i]:.5f}")
print("R² =", r2_4)

# %%
# 1) Warp M into [-1,1] but densify near 1
# M_w = np.tanh((mach - 1)/6)
M_w = mach
M_s = 2*(M_w - M_w.min())/(M_w.max()-M_w.min()) - 1
A_s = 2*(cos_aoa - cos_aoa.min())/(cos_aoa.max()-cos_aoa.min()) - 1

# 2) Build a 5×5 Legendre Vandermonde
degs = [3,3]
V = legvander2d(M_s, A_s, degs).reshape(nsamples, -1)

# 3) Solve with Tikhonov λ=1e-3
λ = 1e-5
a1 = np.linalg.solve(V.T@V + λ*np.eye(V.shape[1]), V.T@Cd)
a2 = np.linalg.lstsq(V, Y, rcond=None)[0]

# 4) Compute R²
Cd_pred1 = V.dot(a1)
Cd_pred2 = V.dot(a2)
print("R² (Legendre+warp+reg) =", r2_score(Cd, Cd_pred1))
print("R² (Legendre+warp) =", r2_score(Cd, Cd_pred2))
print('ΔR² =', r2_score(Cd, Cd_pred1) - r2_score(Cd, Cd_pred2))
print(a1)
print(a2)
